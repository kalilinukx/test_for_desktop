# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
one = [1,2,3,4,5,6,7,8,9]
two = [1,2,3,4,5,3,4,3,2]
three = [1,3,2,4,5,5,6,7,5]

# %%
type(one)
# Out:
# list

# %% [markdown]
# ### Box plot in matplotlib course

# %%
data = list([one,two,three])
data
# Out:
# [[1, 2, 3, 4, 5, 6, 7, 8, 9],
#  [1, 2, 3, 4, 5, 3, 4, 3, 2],
#  [1, 3, 2, 4, 5, 5, 6, 7, 5]]

# %%
plt.boxplot(data)
plt.show()
