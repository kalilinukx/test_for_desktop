# %% [markdown]
# ### Pie charts

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
fruit = ["Apple","Orange","Mango","Guava"]
quantity = [67,34,100,29]
plt.pie(quantity,labels=fruit)
plt.show()

# %%
fruit = ["Apple","Orange","Mango","Guava"]
quantity = [67,34,100,29]
plt.pie(quantity,labels=fruit,autopct="%0.1f%%",colors=["yellow","green","Blue","red","orange"])
plt.show()
